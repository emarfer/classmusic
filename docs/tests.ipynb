# %%
import requests

# %%
params = {
            "user":"sinatxester",
            "api_key":"be357a07c598ec6108cb3774434676aa",
            "format":"json",
            "method":"yoquse"
            }

# %%
LAST_FM_URI = "http://ws.audioscrobbler.com/2.0/"

# %%
requests.get(LAST_FM_URI,params)
# Out:
# <Response [400]>

# %%
requests.get(LAST_FM_URI,params).json()
# Out:
# {'message': 'Invalid Method - No method with that name in this package',
#  'error': 3}
